# %% [markdown]
# <a href="https://colab.research.google.com/github/Aboubacar2012/Data_Analysis_Project/blob/main/Project_1_Explanatory_Data_Analysis_%26_Data_Presentation_(Movies_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns=30
pd.options.display.float_format='{:.2f}'.format

# %%
# Import data
df=pd.read_csv('/content/drive/MyDrive/ml_data/MOVIES/movies_complete.csv')

# %%
df
# Out:
#            id                        title  \
# 0         862                    Toy Story
# 1        8844                      Jumanji
# 2       15602             Grumpier Old Men
# 3       31357            Waiting to Exhale
# 4       11862  Father of the Bride Part II
# ...       ...                          ...
# 44686  439050                       Subdue
# 44687  111109          Century of Birthing
# 44688   67758                     Betrayal
# 44689  227506             Satan Triumphant
# 44690  461257                     Queerama
#
#                                                  tagline release_date  \
# 0                                                    NaN   1995-10-30
# 1              Roll the dice and unleash the excitement!   1995-12-15
# 2      Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3      Friends are the people who let you be yourself...   1995-12-22
# 4      Just When His World Is Back To Normal... He's ...   1995-02-10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44691 entries, 0 to 44690
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     44691 non-null  int64
#  1   title                  44691 non-null  object
#  2   tagline                20284 non-null  object
#  3   release_date           44657 non-null  object
#  4   genres                 42586 non-null  object
#  5   belongs_to_collection  4463 non-null   object
#  6   original_language      44681 non-null  object
#  7   budget_musd            8854 non-null   float64
#  8   revenue_musd           7385 non-null   float64
#  9   production_companies   33356 non-null  object
#  10  production_countries   38835 non-null  object
#  11  vote_count             44691 non-null  float64
#  12  vote_average           42077 non-null  float64
#  13  popularity             44691 non-null  float64
# ...

# %% [markdown]
# #### FEATURES

# %% [markdown]
# - id: The ID of the movie (clear/unique identifier)
# - title: The official title of the movie.
# - tagline: The of the movie.
# - release_date: Theatrical Realease Date of the movie.
# - genres: Genres associated with movie.
# - belongs_to_collection: Gives information on the movie series/franchise the particular to.
# - original_language: The language in which the movie was originally shot in.
# - budget_musd: The budget of the movie in million dollars
# - revenue_musd: The total revenue of the movie in million dollars.
# - production_companies:Production companies involved with the making of the movie;
# - production_countries: Countries where the movie was shot in/produced in
# - vote_count:the number rating of the movie.
# - popularity: The popularity Score assigned by TMDB
# - runtime: The runtime of the movie in minutes.
# - overview : A brief blurb of the movie
# - spoken_languages:Spoken languages in the film
# - poster_path: The URL of the poster image.
# - cast : (Main) Actors appearing in the movie
# - cast_size:number of Actors appearing in the movie.
# - director : Director of the movie.
# - crew_size:Size of the film crew(incl.director, excl. actors)

# %%
df.genres[1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df['genres'][1]
# Out:
# 'Adventure|Fantasy|Family'

# %%
df.cast[1]
# Out:
# 'Robin Williams|Jonathan Hyde|Kirsten Dunst|Bradley Pierce|Bonnie Hunt|Bebe Neuwirth|David Alan Grier|Patricia Clarkson|Adam Hann-Byrd|Laura Bell Bundy|James Handy|Gillian Barber|Brandon Obray|Cyrus Thiedeke|Gary Joseph Thorup|Leonard Zola|Lloyd Berry|Malcolm Stewart|Annabel Kershaw|Darryl Henriques|Robyn Driscoll|Peter Bryant|Sarah Gilson|Florica Vlad|June Lion|Brenda Lockmuller'

# %%
# Summary statistics of numerics values
df.describe().T
# Out:
#                 count      mean       std  min      25%      50%       75%  \
# id           44691.00 107186.24 111806.36 2.00 26033.50 59110.00 154251.00
# budget_musd   8854.00     21.67     34.36 0.00     2.00     8.20     25.00
# revenue_musd  7385.00     68.97    146.61 0.00     2.41    16.87     67.64
# vote_count   44691.00    111.65    495.32 0.00     3.00    10.00     35.00
# vote_average 42077.00      6.00      1.28 0.00     5.30     6.10      6.80
# popularity   44691.00      2.96      6.04 0.00     0.40     1.15      3.77
# runtime      43179.00     97.57     34.65 1.00    86.00    95.00    107.00
# cast_size    44691.00     12.48     12.12 0.00     6.00    10.00     15.00
# crew_size    44691.00     10.31     15.89 0.00     2.00     6.00     12.00
#
#                    max
# id           469172.00
# budget_musd     380.00
# revenue_musd   2787.97
# vote_count    14075.00
# vote_average     10.00
# popularity      547.49
# runtime        1256.00
# cast_size       313.00
# ...

# %%
# Summary statistics of non-numerics values
df.describe(include='object').T
# Out:
#                        count unique  \
# title                  44691  41605
# tagline                20284  20171
# release_date           44657  17225
# genres                 42586   4044
# belongs_to_collection   4463   1691
# original_language      44681     89
# production_companies   33356  22537
# production_countries   38835   2377
# overview               43740  43715
# spoken_languages       41094   1828
# poster_path            44467  44456
# cast                   42502  42166
# director               43960  17349
#
#                                                                      top  \
# title                                                         Cinderella
# tagline                                           Based on a true story.
# release_date                                                  2008-01-01
# genres                                                             Drama
# belongs_to_collection                                    The Bowery Boys
# ...

# %%
df.hist(figsize=(20,12), bins=100)
plt.show()

# %%
# Count values
df.budget_musd.value_counts()
# Out:
# 5.00     286
# 10.00    258
# 20.00    243
# 2.00     241
# 15.00    226
#         ...
# 12.20      1
# 1.20       1
# 1.25       1
# 10.92      1
# 6.85       1
# Name: budget_musd, Length: 1218, dtype: int64

# %%
# Count values (frequent values) of budget_musd with in NaN
df.budget_musd.value_counts(dropna=False).head(20)
# Out:
# nan      35837
# 5.00       286
# 10.00      258
# 20.00      243
# 2.00       241
# 15.00      226
# 3.00       220
# 25.00      206
# 1.00       195
# 30.00      189
# 4.00       180
# 6.00       173
# 12.00      171
# 40.00      166
# 8.00       155
# 0.50       141
# 35.00      141
# 7.00       137
# 50.00      124
# 1.50       119
# Name: budget_musd, dtype: int64

# %%
# Count values (frequente values) of revenue_musd with in NaN
df.revenue_musd.value_counts(dropna=False).head(20)
# Out:
# nan      37306
# 12.00       20
# 11.00       19
# 10.00       19
# 2.00        18
# 6.00        17
# 5.00        14
# 0.50        13
# 8.00        13
# 0.00        12
# 14.00       12
# 7.00        11
# 3.00        10
# 20.00       10
# 1.00        10
# 4.00         9
# 0.00         9
# 1.50         9
# 25.00        8
# 16.00        8
# Name: revenue_musd, dtype: int64

# %%
#Filter title== Jumanji (Method 1)
df[df.title=='Jumanji']
# Out:
#      id    title                                    tagline release_date  \
# 1  8844  Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 1        65.00        262.80
#
#                                 production_companies  \
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 1  United States of America     2413.00          6.90       17.02   104.00
#
#                                             overview  spoken_languages  \
# 1  When siblings Judy and Peter discover an encha...  English|Français
#
#                                          poster_path  \
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
#
#                                                 cast  cast_size  crew_size  \
# ...

# %%
# Method 2 
df[df['title']=='Jumanji']
# Out:
#      id    title                                    tagline release_date  \
# 1  8844  Jumanji  Roll the dice and unleash the excitement!   1995-12-15
#
#                      genres belongs_to_collection original_language  \
# 1  Adventure|Fantasy|Family                   NaN                en
#
#    budget_musd  revenue_musd  \
# 1        65.00        262.80
#
#                                 production_companies  \
# 1  TriStar Pictures|Teitler Film|Interscope Commu...
#
#        production_countries  vote_count  vote_average  popularity  runtime  \
# 1  United States of America     2413.00          6.90       17.02   104.00
#
#                                             overview  spoken_languages  \
# 1  When siblings Judy and Peter discover an encha...  English|Français
#
#                                          poster_path  \
# 1  <img src='http://image.tmdb.org/t/p/w185//vgpX...
#
#                                                 cast  cast_size  crew_size  \
# ...

# %%
df[df['title']=='Cinderella']
# Out:
#            id       title                             tagline release_date  \
# 984     11224  Cinderella  The greatest love story ever told.   1950-03-04
# 12988   42884  Cinderella                                 NaN   1997-11-02
# 23254   92349  Cinderella                                 NaN   1914-12-28
# 23265  105875  Cinderella          The version children love!   2002-08-06
# 28073  261985  Cinderella                                 NaN   2011-10-30
# 28340  150689  Cinderella     Midnight is just the beginning.   2015-03-12
# 33805   42651  Cinderella                                 NaN   1947-11-28
# 35114   44459  Cinderella                                 NaN   1957-03-31
# 35116  289673  Cinderella                                 NaN   2000-01-01
# 40439  114108  Cinderella                                 NaN   1899-10-01
# 44633   98604  Cinderella                                 NaN   2012-02-14
#
# ...

# %% [markdown]
# ######The best and the worst movies...(Part 1)

# %%
from IPython.display import HTML

# %%
df_best=df[['poster_path','title','budget_musd','revenue_musd','vote_count','vote_average','popularity']].copy()
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        373.55     5415.00
# 1                          Jumanji        65.00        262.80     2413.00
# ...

# %%
df_best['revenue_musd']=df.revenue_musd.sub(df.budget_musd)
df_best['return']=df.revenue_musd.div(df.budget_musd)

# %%
df_best
# Out:
#                                              poster_path  \
# 0      <img src='http://image.tmdb.org/t/p/w185//uXDf...
# 1      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# 2      <img src='http://image.tmdb.org/t/p/w185//1FSX...
# 3      <img src='http://image.tmdb.org/t/p/w185//4wjG...
# 4      <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                  ...
# 44686  <img src='http://image.tmdb.org/t/p/w185//pfC8...
# 44687  <img src='http://image.tmdb.org/t/p/w185//xZkm...
# 44688  <img src='http://image.tmdb.org/t/p/w185//eGga...
# 44689  <img src='http://image.tmdb.org/t/p/w185//aorB...
# 44690  <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
#                              title  budget_musd  revenue_musd  vote_count  \
# 0                        Toy Story        30.00        343.55     5415.00
# 1                          Jumanji        65.00        197.80     2413.00
# ...

# %%
#Rename colummns headers
df_best.columns=['','Title','Buget','Revenue','Vote','Average Rating','Popularity','ROI']
df_best.set_index('Title', inplace=True)

# %%
df_best
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
# ...                                                                        ...
# Subdue                       <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing          <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                     <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant             <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                     <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
df_best.iloc[0,0]
# Out:
# "<img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'>"

# %%
subset=df_best.iloc[:5,:2]
subset
# Out:
#                                                                                 \
# Title
# Toy Story                    <img src='http://image.tmdb.org/t/p/w185//uXDf...
# Jumanji                      <img src='http://image.tmdb.org/t/p/w185//vgpX...
# Grumpier Old Men             <img src='http://image.tmdb.org/t/p/w185//1FSX...
# Waiting to Exhale            <img src='http://image.tmdb.org/t/p/w185//4wjG...
# Father of the Bride Part II  <img src='http://image.tmdb.org/t/p/w185//lf9R...
#
#                              Buget
# Title
# Toy Story                    30.00
# Jumanji                      65.00
# Grumpier Old Men               nan
# Waiting to Exhale            16.00
# Father of the Bride Part II    nan

# %%
HTML(subset.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Buget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Toy Story</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//uXDfjJbdP4ijW5hWSBrPrlKpxab.jpg' style='height:100px;'></td>
#       <td>30.00</td>
#     </tr>
#     <tr>
#       <th>Jumanji</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//vgpXmVaVyUL7GGiDeiK1mKEKzcX.jpg' style='height:100px;'></td>
#       <td>65.00</td>
#     </tr>
#     <tr>
#       <th>Grumpier Old Men</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1FSXpj5e8l4KH6nVFO5SPUeraOt.jpg' style='height:100px;'></td>
#       <td>nan</td>
#     </tr>
#     <tr>
#       <th>Waiting to Exhale</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4wjGMwPsdlvi025ZqR4rXnFDvBz.jpg' style='height:100px;'></td>
# ...

# %% [markdown]
# #####Sorting

# %%
# Sort by Average Rating
df_best.sort_values(by='Average Rating', ascending=False)
# Out:
#                                                                                                \
# Title
# Portrait of a Young Man in Three Movements                                                NaN
# Brave Revolutionary                         <img src='http://image.tmdb.org/t/p/w185//zAb2...
# Other Voices Other Rooms                    <img src='http://image.tmdb.org/t/p/w185//4ifP...
# The Lion of Thebes                          <img src='http://image.tmdb.org/t/p/w185//tdOc...
# Katt Williams: Priceless: Afterlife         <img src='http://image.tmdb.org/t/p/w185//wKrH...
# ...                                                                                       ...
# Altar of Fire                               <img src='http://image.tmdb.org/t/p/w185//iJ78...
# The Wonders of Aladdin                      <img src='http://image.tmdb.org/t/p/w185//AvfX...
# Deep Hearts                                 <img src='http://image.tmdb.org/t/p/w185//8jI4...
# ...

# %%
# Sort by ROI
df_best.sort_values(by='ROI', ascending=False)
# Out:
#                                                                             \
# Title
# Less Than Zero           <img src='http://image.tmdb.org/t/p/w185//1GY0...
# Modern Times             <img src='http://image.tmdb.org/t/p/w185//7uoi...
# Welcome to Dongmakgol    <img src='http://image.tmdb.org/t/p/w185//5iGV...
# Aquí Entre Nos           <img src='http://image.tmdb.org/t/p/w185//oflx...
# The Karate Kid, Part II  <img src='http://image.tmdb.org/t/p/w185//mSne...
# ...                                                                    ...
# Subdue                   <img src='http://image.tmdb.org/t/p/w185//pfC8...
# Century of Birthing      <img src='http://image.tmdb.org/t/p/w185//xZkm...
# Betrayal                 <img src='http://image.tmdb.org/t/p/w185//eGga...
# Satan Triumphant         <img src='http://image.tmdb.org/t/p/w185//aorB...
# Queerama                 <img src='http://image.tmdb.org/t/p/w185//oxFE...
#
# ...

# %%
# Sort by ROI with buget >= 5 millions (Method 1)
df_best.loc[df_best.Buget>=5].sort_values(by='ROI', ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# ...

# %%
#Method 2
df_best[df_best['Buget']>=5].sort_values(by='ROI', ascending=False)
# Out:
#                                                                                                    \
# Title
# E.T. the Extra-Terrestrial                      <img src='http://image.tmdb.org/t/p/w185//cBfk...
# My Big Fat Greek Wedding                        <img src='http://image.tmdb.org/t/p/w185//3TB2...
# Star Wars                                       <img src='http://image.tmdb.org/t/p/w185//6FfC...
# Jaws                                            <img src='http://image.tmdb.org/t/p/w185//s2xc...
# Crocodile Dundee                                <img src='http://image.tmdb.org/t/p/w185//kiwO...
# ...                                                                                           ...
# The Blonde with Bare Breasts                    <img src='http://image.tmdb.org/t/p/w185//zBjp...
# Detroit                                         <img src='http://image.tmdb.org/t/p/w185//7APL...
# ...

# %% [markdown]
# ##### Fill NaN by O

# %%
df_best.isnull().sum()
# Out:
#                     224
# Buget             35837
# Revenue           39320
# Vote                  0
# Average Rating     2614
# Popularity            0
# ROI               39320
# dtype: int64

# %%
df_best.Buget.fillna(0,inplace=True)
df_best.Vote.fillna(0, inplace=True)

# %%
df_best.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 44691 entries, Toy Story to Queerama
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0                   44467 non-null  object
#  1   Buget           44691 non-null  float64
#  2   Revenue         5371 non-null   float64
#  3   Vote            44691 non-null  float64
#  4   Average Rating  42077 non-null  float64
#  5   Popularity      44691 non-null  float64
#  6   ROI             5371 non-null   float64
# dtypes: float64(6), object(1)
# memory usage: 4.0+ MB

# %%
# Best and worst Movies
# Let's define a function
def best_worst(n, by, ascending=False, min_bud=0, min_votes=0):
  df2=df_best.loc[(df_best.Buget>=min_bud)&(df_best.Vote>=min_votes),
                  ['', by]].sort_values(by=by, ascending=ascending).head(n).copy()
  return HTML(df2.to_html(escape=False))

# %%
#best_worst(df_best)

# %% [markdown]
# #####The best and the worst movies..(Part 2)

# %% [markdown]
# ######Movies Top 5 - Highest Revenue

# %%
best_worst(5, by='Revenue')
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Revenue</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Avatar</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//btnl50ZDJDSCal2NLQIYWw0XxvH.jpg' style='height:100px;'></td>
#       <td>2550.97</td>
#     </tr>
#     <tr>
#       <th>Star Wars: The Force Awakens</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9rd002JS49RwDW944fF1wjU8iTV.jpg' style='height:100px;'></td>
#       <td>1823.22</td>
#     </tr>
#     <tr>
#       <th>Titanic</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//9xjZS2rlVxm8SFx8kPC3aIGCOYQ.jpg' style='height:100px;'></td>
#       <td>1645.03</td>
#     </tr>
#     <tr>
#       <th>Jurassic World</th>
# ...

# %% [markdown]
# ######Movies Top 5 - Highest Budget

# %%
best_worst(5,"Buget")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Buget</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Pirates of the Caribbean: On Stranger Tides</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//keGfSvCmYj7CvdRx36OdVrAEibE.jpg' style='height:100px;'></td>
#       <td>380.00</td>
#     </tr>
#     <tr>
#       <th>Pirates of the Caribbean: At World's End</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//oVh3REsCwJwmrTkZ9OkkeKiAE02.jpg' style='height:100px;'></td>
#       <td>300.00</td>
#     </tr>
#     <tr>
#       <th>Avengers: Age of Ultron</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//4ssDuvEDkSArWEdyBl2X5EHvYKU.jpg' style='height:100px;'></td>
#       <td>280.00</td>
#     </tr>
#     <tr>
#       <th>Superman Returns</th>
# ...

# %% [markdown]
# ######Movies Top 5 - Highest Profit

# %%
best_worst(5, "ROI")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Less Than Zero</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'></td>
#       <td>12396383.00</td>
#     </tr>
#     <tr>
#       <th>Modern Times</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'></td>
#       <td>8500000.00</td>
#     </tr>
#     <tr>
#       <th>Welcome to Dongmakgol</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'></td>
#       <td>4197476.62</td>
#     </tr>
#     <tr>
#       <th>Aquí Entre Nos</th>
# ...

# %% [markdown]
# ######Movies Top 5 - Lowest Profit

# %%
#Lowest profit 
best_worst(5, "ROI", ascending=True)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Chasing Liberty</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7qzvS9QKkiDcz1K8EY9Y6ZXkUeD.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>The Cookout</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//eUVEPES8KhnXbTG3G74UZfVQRb7.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Never Talk to Strangers</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//IHZZLIxqF3ByEZV57RApvfh7uu.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>To Rob a Thief</th>
# ...

# %% [markdown]
# ######Movies Top 5-Highest ROI

# %%
# Highest ROI
best_worst(5, "ROI", min_bud=0)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Less Than Zero</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//1GY0ZhAxOR2RgxGnOkeKoKb2mFM.jpg' style='height:100px;'></td>
#       <td>12396383.00</td>
#     </tr>
#     <tr>
#       <th>Modern Times</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7uoiKOEjxBBW0AgDGQWrlfGQ90w.jpg' style='height:100px;'></td>
#       <td>8500000.00</td>
#     </tr>
#     <tr>
#       <th>Welcome to Dongmakgol</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//5iGVw8AdnUJ3xNaZ5iipfsv2e5.jpg' style='height:100px;'></td>
#       <td>4197476.62</td>
#     </tr>
#     <tr>
#       <th>Aquí Entre Nos</th>
# ...

# %%
# Movies Top 5 - Lowest ROI
best_worst(5, "ROI", ascending=True, min_bud=50) # Minimum ROI 50 Billions
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>ROI</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Foodfight!</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//R1zn75Yz4wpdd85byqhP7mT6No.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Metropolis</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//3F5OKhpC6rqq5KdjgixNbqjWSWz.jpg' style='height:100px;'></td>
#       <td>0.01</td>
#     </tr>
#     <tr>
#       <th>Lolita</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//unGWuk8kax8r4PlbGJL9y6WnfFx.jpg' style='height:100px;'></td>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Child 44</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//qqGhMt31HVUN3WnH0L2r0OWq38E.jpg' style='height:100px;'></td>
#       <td>0.07</td>
# ...

# %%
# Movies Top 5 - Lowest Rating
best_worst(5, "Average Rating", ascending=True, min_votes=0)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Dance, Fools, Dance</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//znLNTt8o2Bkfv5eCiCTEZdqNnye.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>.hack Liminality: In the Case of Mai Minase</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//mij7uE2vjbumQOeiLhY3M8HT5V0.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Lucrezia Borgia</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//z3k5rkCJxNWAFua7MFgB8bi9AkX.jpg' style='height:100px;'></td>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Joe and Max</th>
# ...

# %%
# vote =20 and min_bud=0
best_worst(5, "Average Rating", ascending=True, min_votes=20, min_bud=0)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Average Rating</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Saving Christmas</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//6MLSD1OYGDWkCk05m7vA1xCrfKr.jpg' style='height:100px;'></td>
#       <td>1.70</td>
#     </tr>
#     <tr>
#       <th>Superbabies: Baby Geniuses 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//7viULokoVzqrgVj0EljfXDzEKMk.jpg' style='height:100px;'></td>
#       <td>1.90</td>
#     </tr>
#     <tr>
#       <th>Manos: The Hands of Fate</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//dcDR1ZhZvA7HQvxQ17hzFjeCNHx.jpg' style='height:100px;'></td>
#       <td>2.00</td>
#     </tr>
#     <tr>
#       <th>Birdemic: Shock and Terror</th>
# ...

# %% [markdown]
# ######Movies Top 5 - Most Popular

# %%
best_worst(5, "Popularity")
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th>Popularity</th>
#     </tr>
#     <tr>
#       <th>Title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Minions</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tMaGZ2HR8HAFwkx4YRib0CDVfNT.jpg' style='height:100px;'></td>
#       <td>547.49</td>
#     </tr>
#     <tr>
#       <th>Wonder Woman</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//gfJGlDaHuWimErCr5Ql0I8x9QSy.jpg' style='height:100px;'></td>
#       <td>294.34</td>
#     </tr>
#     <tr>
#       <th>Beauty and the Beast</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//tWqifoYuwLETmmasnGHO7xBjEtt.jpg' style='height:100px;'></td>
#       <td>287.25</td>
#     </tr>
#     <tr>
#       <th>Baby Driver</th>
# ...

# %% [markdown]
# ###Find your next Movie

# %% [markdown]
# #####Search 1 : Science Fiction Action Movies with Bruce Willis (High Rating)

# %%
df.genres[0]
# Out:
# 'Animation|Comedy|Family'

# %%
# Create a mask with keyword of Action and Science Fiction
# Mask Genres
mask_genres=df.genres.str.contains('Action') & df.genres.str.contains('Science Fiction')
mask_genres
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: genres, Length: 44691, dtype: bool

# %%
df.cast[0]
# Out:
# 'Tom Hanks|Tim Allen|Don Rickles|Jim Varney|Wallace Shawn|John Ratzenberger|Annie Potts|John Morris|Erik von Detten|Laurie Metcalf|R. Lee Ermey|Sarah Freeman|Penn Jillette'

# %%
# Mask for Actors
mask_actor=df.cast.str.contains('Bruce Willis')
mask_actor
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690      NaN
# Name: cast, Length: 44691, dtype: object

# %%
df.loc[mask_actor & mask_genres, ['title','vote_average']].sort_values(by='vote_average', ascending=False)
# Out:
#                        title  vote_average
# 1448       The Fifth Element          7.30
# 19218                 Looper          6.60
# 1786              Armageddon          6.50
# 14135             Surrogates          5.90
# 20333  G.I. Joe: Retaliation          5.40
# 27619                   Vice          4.10

# %%
bruce=df.loc[mask_actor&mask_genres, ['title','poster_path','vote_average']].sort_values(by='vote_average', ascending=False)
bruce
# Out:
#                        title  \
# 1448       The Fifth Element
# 19218                 Looper
# 1786              Armageddon
# 14135             Surrogates
# 20333  G.I. Joe: Retaliation
# 27619                   Vice
#
#                                              poster_path  vote_average
# 1448   <img src='http://image.tmdb.org/t/p/w185//fPtl...          7.30
# 19218  <img src='http://image.tmdb.org/t/p/w185//sNjL...          6.60
# 1786   <img src='http://image.tmdb.org/t/p/w185//fMtO...          6.50
# 14135  <img src='http://image.tmdb.org/t/p/w185//v3Z0...          5.90
# 20333  <img src='http://image.tmdb.org/t/p/w185//3rWI...          5.40
# 27619  <img src='http://image.tmdb.org/t/p/w185//nPqN...          4.10

# %%
HTML(bruce.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>vote_average</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1448</th>
#       <td>The Fifth Element</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fPtlCO1yQtnoLHOwKtWz7db6RGU.jpg' style='height:100px;'></td>
#       <td>7.30</td>
#     </tr>
#     <tr>
#       <th>19218</th>
#       <td>Looper</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sNjL6SqErDBE8OUZlrDLkexfsCj.jpg' style='height:100px;'></td>
#       <td>6.60</td>
#     </tr>
#     <tr>
#       <th>1786</th>
#       <td>Armageddon</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//fMtOCd0EAdAzKtGLQiHjSUvbdNc.jpg' style='height:100px;'></td>
#       <td>6.50</td>
#     </tr>
#     <tr>
#       <th>14135</th>
#       <td>Surrogates</td>
# ...

# %% [markdown]
# ######Search 2 : Movies with Uma Thurman and directed by Quentin Tarantino (low runtime)

# %%
df.director
# Out:
# 0           John Lasseter
# 1            Joe Johnston
# 2           Howard Deutch
# 3         Forest Whitaker
# 4           Charles Shyer
#                ...
# 44686    Hamid Nematollah
# 44687            Lav Diaz
# 44688      Mark L. Lester
# 44689    Yakov Protazanov
# 44690       Daisy Asquith
# Name: director, Length: 44691, dtype: object

# %%
#Mask director 
mask_director=df.director=='Quentin Tarantino'
mask_director
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: director, Length: 44691, dtype: bool

# %%
# mask Uma Thurman
mask_actors=df.cast.str.contains('Uma Thurman')

# %%
quentin=df.loc[mask_director & mask_actors,['title','poster_path','runtime']].sort_values(by='runtime').set_index('title')

# %%
quentin
# Out:
#                                                          poster_path  runtime
# title
# Kill Bill: Vol. 1  <img src='http://image.tmdb.org/t/p/w185//v7Ta...   111.00
# Kill Bill: Vol. 2  <img src='http://image.tmdb.org/t/p/w185//2yhg...   136.00
# Pulp Fiction       <img src='http://image.tmdb.org/t/p/w185//d5iI...   154.00

# %%
HTML(quentin.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>poster_path</th>
#       <th>runtime</th>
#     </tr>
#     <tr>
#       <th>title</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Kill Bill: Vol. 1</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//v7TaX8kXMXs5yFFGR41guUDNcnB.jpg' style='height:100px;'></td>
#       <td>111.00</td>
#     </tr>
#     <tr>
#       <th>Kill Bill: Vol. 2</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//2yhg0mZQMhDyvUQ4rG1IZ4oIA8L.jpg' style='height:100px;'></td>
#       <td>136.00</td>
#     </tr>
#     <tr>
#       <th>Pulp Fiction</th>
#       <td><img src='http://image.tmdb.org/t/p/w185//d5iIlFn5s0ImszYzBPb8JPIfbXD.jpg' style='height:100px;'></td>
#       <td>154.00</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ######Search 3 : Most Successful Pixar studio Movies between 2010 and 2015 (high Revenue)

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.production_companies
# Out:
# 0                                  Pixar Animation Studios
# 1        TriStar Pictures|Teitler Film|Interscope Commu...
# 2                              Warner Bros.|Lancaster Gate
# 3                   Twentieth Century Fox Film Corporation
# 4                Sandollar Productions|Touchstone Pictures
#                                ...
# 44686                                                  NaN
# 44687                                          Sine Olivia
# 44688                              American World Pictures
# 44689                                            Yermoliev
# 44690                                                  NaN
# Name: production_companies, Length: 44691, dtype: object

# %%
# Mask contains the keyword Pixar
mask_studio=df.production_companies.str.contains('Pixar').fillna(False)
df[mask_studio].head(2)
# Out:
#         id         title                                         tagline  \
# 0      862     Toy Story                                             NaN
# 2219  9487  A Bug's Life  An epic presentation of miniature proportions.
#
#      release_date                             genres belongs_to_collection  \
# 0      1995-10-30            Animation|Comedy|Family  Toy Story Collection
# 2219   1998-11-25  Adventure|Animation|Comedy|Family                   NaN
#
#      original_language  budget_musd  revenue_musd  \
# 0                   en        30.00        373.55
# 2219                en       120.00        363.26
#
#                               production_companies      production_countries  \
# 0                          Pixar Animation Studios  United States of America
# 2219  Walt Disney Pictures|Pixar Animation Studios  United States of America
#
#       vote_count  vote_average  popularity  runtime  \
# 0        5415.00          7.70       21.95    81.00
# ...

# %%
# Date of release
df.release_date
# Out:
# 0        1995-10-30
# 1        1995-12-15
# 2        1995-12-22
# 3        1995-12-22
# 4        1995-02-10
#             ...
# 44686           NaN
# 44687    2011-11-17
# 44688    2003-08-01
# 44689    1917-10-21
# 44690    2017-06-09
# Name: release_date, Length: 44691, dtype: object

# %%
mask_time=df.release_date.between('2010-01-01','2015-12-31')
df[mask_time].head(2)
# Out:
#           id          title tagline release_date         genres  \
# 859    79782         Venice     NaN   2010-05-25  Drama|Romance
# 1071  141210  The Sleepover     NaN   2013-10-12  Comedy|Horror
#
#      belongs_to_collection original_language  budget_musd  revenue_musd  \
# 859                    NaN                en          nan           nan
# 1071                   NaN                en          nan           nan
#
#      production_companies production_countries  vote_count  vote_average  \
# 859                   NaN                  NaN        4.00          7.50
# 1071                  NaN                  NaN        1.00          8.00
#
#       popularity  runtime                                           overview  \
# 859         0.15   110.00  An atmospheric coming-of-age story featuring a...
# 1071        0.14     6.00  The town of Derry has a secret, but no one tol...
#
#      spoken_languages                                        poster_path  \
# ...

# %%
pixar=df.loc[mask_studio&mask_time, ['title','poster_path','revenue_musd','release_date']].sort_values(by='revenue_musd', ascending=False)
pixar
# Out:
#                             title  \
# 15236                 Toy Story 3
# 29957                  Inside Out
# 20888         Monsters University
# 17220                      Cars 2
# 18900                       Brave
# 30388           The Good Dinosaur
# 16392                 Day & Night
# 21694           The Blue Umbrella
# 21697        Toy Story of Terror!
# 22489                     La luna
# 24252           Hawaiian Vacation
# 24254                   Small Fry
# 25515             Partysaurus Rex
# 25516        The Legend of Mor'du
# 25517  Toy Story That Time Forgot
# 31803                        Lava
# 34560         Sanjay's Super Team
# 40259                   Air Mater
# 40675         Riley's First Date?
#
#                                              poster_path  revenue_musd  \
# 15236  <img src='http://image.tmdb.org/t/p/w185//amY0...       1066.97
# 29957  <img src='http://image.tmdb.org/t/p/w185//lRHE...        857.61
# ...

# %%
HTML(pixar.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>revenue_musd</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>15236</th>
#       <td>Toy Story 3</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//amY0NH1ksd9xJ9boXAMmods6U0D.jpg' style='height:100px;'></td>
#       <td>1066.97</td>
#       <td>2010-06-16</td>
#     </tr>
#     <tr>
#       <th>29957</th>
#       <td>Inside Out</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//lRHE0vzf3oYJrhbsHXjIkF4Tl5A.jpg' style='height:100px;'></td>
#       <td>857.61</td>
#       <td>2015-06-09</td>
#     </tr>
#     <tr>
#       <th>20888</th>
#       <td>Monsters University</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//tyHHjZEzJutWggujN1KP0a1jfLX.jpg' style='height:100px;'></td>
#       <td>743.56</td>
#       <td>2013-06-20</td>
#     </tr>
# ...

# %% [markdown]
# ######Search 4 : Action or Thriller Movie with original Lang English and Minium Rating of 7.5 (most recent)

# %%
mask_action_thriller=df.genres.str.contains('Actions')|df.genres.str.contains('Thriller')
df[mask_action_thriller].sample(2)
# Out:
#          id                   title  \
# 12257  3575  The Return of Doctor X
# 3801   2134        The Time Machine
#
#                                               tagline release_date  \
# 12257  HE ROSE FROM THE DEAD...TO HAUNT THE LIVING!!!   1939-12-02
# 3801        You Will Orbit into the Fantastic Future!   1960-08-17
#
#                                                   genres  \
# 12257                                    Horror|Thriller
# 3801   Thriller|Adventure|Fantasy|Science Fiction|Rom...
#
#       belongs_to_collection original_language  budget_musd  revenue_musd  \
# 12257                   NaN                en          nan           nan
# 3801                    NaN                en         0.75           nan
#
#                            production_companies      production_countries  \
# 12257      First National Pictures|Warner Bros.  United States of America
# 3801   George Pal Productions|Galaxy Films Inc.  United States of America
#
# ...

# %%
mask_lang=df.original_language=='en'

# %%
mask_vote_av=df.vote_average>=7.5

# %%
mask_vote_co=df.vote_count>=10

# %%
next_mov=df.loc[mask_action_thriller & mask_action_thriller & mask_vote_av&mask_vote_co,
                ['title','poster_path','genres','vote_average','vote_count','release_date']].sort_values(by='title', ascending=False)
next_mov
# Out:
#                          title  \
# 9950                        Él
# 5297                         Z
# 2885                   Yojimbo
# 3078        Woman in the Dunes
# 24630               Wild Tales
# ...                        ...
# 32670                A Million
# 7891             A Man Escaped
# 27503            @Suicide Room
# 34335  3 ½ Minutes, 10 Bullets
# 37677                 11.22.63
#
#                                              poster_path  \
# 9950   <img src='http://image.tmdb.org/t/p/w185//yaTI...
# 5297   <img src='http://image.tmdb.org/t/p/w185//sHPw...
# 2885   <img src='http://image.tmdb.org/t/p/w185//tN7k...
# 3078   <img src='http://image.tmdb.org/t/p/w185//rE6v...
# 24630  <img src='http://image.tmdb.org/t/p/w185//pvSt...
# ...                                                  ...
# 32670  <img src='http://image.tmdb.org/t/p/w185//xLWt...
# 7891   <img src='http://image.tmdb.org/t/p/w185//yPVp...
# 27503  <img src='http://image.tmdb.org/t/p/w185//6BUy...
# ...

# %%
HTML(next_mov.to_html(escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>poster_path</th>
#       <th>genres</th>
#       <th>vote_average</th>
#       <th>vote_count</th>
#       <th>release_date</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>9950</th>
#       <td>Él</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//yaTI9GxxWREmQgMTIGquO0BXSJn.jpg' style='height:100px;'></td>
#       <td>Thriller|Drama|Romance</td>
#       <td>7.80</td>
#       <td>18.00</td>
#       <td>1953-07-09</td>
#     </tr>
#     <tr>
#       <th>5297</th>
#       <td>Z</td>
#       <td><img src='http://image.tmdb.org/t/p/w185//sHPwsRJvKUYrHAnXO0oFkPtnFjI.jpg' style='height:100px;'></td>
#       <td>Drama|History|Thriller</td>
#       <td>8.00</td>
#       <td>87.00</td>
#       <td>1969-02-26</td>
#     </tr>
#     <tr>
#       <th>2885</th>
#       <td>Yojimbo</td>
# ...

# %% [markdown]
# ######What are the most common Words in Movie Titles and Taglines? (WORDCLOUD)

# %%
from wordcloud import WordCloud

# %%
df.head()
# Out:
#       id                        title  \
# 0    862                    Toy Story
# 1   8844                      Jumanji
# 2  15602             Grumpier Old Men
# 3  31357            Waiting to Exhale
# 4  11862  Father of the Bride Part II
#
#                                              tagline release_date  \
# 0                                                NaN   1995-10-30
# 1          Roll the dice and unleash the excitement!   1995-12-15
# 2  Still Yelling. Still Fighting. Still Ready for...   1995-12-22
# 3  Friends are the people who let you be yourself...   1995-12-22
# 4  Just When His World Is Back To Normal... He's ...   1995-02-10
#
#                      genres           belongs_to_collection original_language  \
# 0   Animation|Comedy|Family            Toy Story Collection                en
# 1  Adventure|Fantasy|Family                             NaN                en
# 2            Romance|Comedy       Grumpy Old Men Collection                en
# ...

# %%
df.columns
# Out:
# Index(['id', 'title', 'tagline', 'release_date', 'genres',
#        'belongs_to_collection', 'original_language', 'budget_musd',
#        'revenue_musd', 'production_companies', 'production_countries',
#        'vote_count', 'vote_average', 'popularity', 'runtime', 'overview',
#        'spoken_languages', 'poster_path', 'cast', 'cast_size', 'crew_size',
#        'director'],
#       dtype='object')

# %%
df.tagline[1]
# Out:
# 'Roll the dice and unleash the excitement!'

# %%
df.overview[1]
# Out:
# "When siblings Judy and Peter discover an enchanted board game that opens the door to a magical world, they unwittingly invite Alan -- an adult who's been trapped inside the game for 26 years -- into their living room. Alan's only hope for freedom is to finish the game, which proves risky as all three find themselves running from giant rhinoceroses, evil monkeys and other terrifying creatures."

# %%
df.title.isna()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 44686    False
# 44687    False
# 44688    False
# 44689    False
# 44690    False
# Name: title, Length: 44691, dtype: bool

# %%
title=df.title.dropna()
overview=df.overview.dropna()
tagline=df.tagline.dropna()

# %%
title
# Out:
# 0                          Toy Story
# 1                            Jumanji
# 2                   Grumpier Old Men
# 3                  Waiting to Exhale
# 4        Father of the Bride Part II
#                     ...
# 44686                         Subdue
# 44687            Century of Birthing
# 44688                       Betrayal
# 44689               Satan Triumphant
# 44690                       Queerama
# Name: title, Length: 44691, dtype: object

# %%
' '.join(title)
# Out:
# 'Toy Story Jumanji Grumpier Old Men Waiting to Exhale Father of the Bride Part II Heat Sabrina Tom and Huck Sudden Death GoldenEye The American President Dracula: Dead and Loving It Balto Nixon Cutthroat Island Casino Sense and Sensibility Four Rooms Ace Ventura: When Nature Calls Money Train Get Shorty Copycat Assassins Powder Leaving Las Vegas Othello Now and Then Persuasion The City of Lost Children Shanghai Triad Dangerous Minds Twelve Monkeys Wings of Courage Babe Carrington Dead Man Walking Across the Sea of Time It Takes Two Clueless Cry, the Beloved Country Richard III Dead Presidents Restoration Mortal Kombat To Die For How To Make An American Quilt Se7en Pocahontas When Night Is Falling The Usual Suspects Guardian Angel Mighty Aphrodite Lamerica The Big Green Georgia Kids of the Round Table Home for the Holidays The Postman The Confessional The Indian in the Cupboard Eye for an Eye Mr. Holland\'s Opus Don\'t Be a Menace to South Central While Drinking Your Juice in the Hood
# ...

# %%
# corpus of title, overview, tagline
title_corpus=' '.join(title)
overview_corpus=' '.join(overview)
tagline_corpus=' '.join(tagline)

# %%
tagline_corpus
# Out:
# 'Roll the dice and unleash the excitement! Still Yelling. Still Fighting. Still Ready for Love. Friends are the people who let you be yourself... and never let you forget it. Just When His World Is Back To Normal... He\'s In For The Surprise Of His Life! A Los Angeles Crime Saga You are cordially invited to the most surprising merger of the year. The Original Bad Boys. Terror goes into overtime. No limits. No fears. No substitutes. Why can\'t the most powerful man in the world have the one thing he wants most? Part Dog. Part Wolf. All Hero. Triumphant in Victory, Bitter in Defeat. He Changed the World, But Lost a Nation. The Course Has Been Set. There Is No Turning Back. Prepare Your Weapons. Summon Your Courage. Discover the Adventure of a Lifetime! No one stays at the top forever. Lose your heart and come to your senses. Twelve outrageous guests. Four scandalous requests. And one lone bellhop, in his first day on the job, who\'s in for the wildest New year\'s Eve of his life. New a
# ...

# %%
# title wordcloud
title_wordcloud=WordCloud(background_color='white', width=10000, height=4000, max_words=200).generate(title_corpus)
title_wordcloud

# %%
#Plot de wordcloud
plt.figure(figsize=(20,8))
plt.imshow(title_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
# overview wordcloud
overview_wordcloud=WordCloud(background_color='white', width=10000, height=4000, max_words=200).generate(overview_corpus)
overview_wordcloud

# %%
#Plot de wordcloud
plt.figure(figsize=(20,8))
plt.imshow(overview_wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()
