# %% [markdown]
# <a href="https://colab.research.google.com/github/Aboubacar2012/Data_Analysis_Project/blob/main/Systeme_Educatif_(World_Bank_Dataset).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
# Importer les données
EdStatsCountrySeries=pd.read_csv('/content/drive/MyDrive/ml_data/P2/EdStatsCountry-Series.csv')
EdStatsCountry=pd.read_csv('/content/drive/MyDrive/ml_data/P2/EdStatsCountry.csv')
EdStatsData=pd.read_csv('/content/drive/MyDrive/ml_data/P2/EdStatsData.csv')
EdStatsFootNote=pd.read_csv('/content/drive/MyDrive/ml_data/P2/EdStatsFootNote.csv')
EdStatsSeries=pd.read_csv('/content/drive/MyDrive/ml_data/P2/EdStatsSeries.csv')

# %%
EdStatsCountrySeries.head()
# Out:
#   CountryCode  ... Unnamed: 3
# 0         ABW  ...        NaN
# 1         ABW  ...        NaN
# 2         AFG  ...        NaN
# 3         AFG  ...        NaN
# 4         AFG  ...        NaN
#
# [5 rows x 4 columns]

# %%
EdStatsCountrySeries.tail()
# Out:
#     CountryCode  ... Unnamed: 3
# 608         ZAF  ...        NaN
# 609         ZMB  ...        NaN
# 610         ZMB  ...        NaN
# 611         ZWE  ...        NaN
# 612         ZWE  ...        NaN
#
# [5 rows x 4 columns]

# %%
EdStatsCountry.head()
# Out:
#   Country Code   Short Name  ... Latest water withdrawal data Unnamed: 31
# 0          ABW        Aruba  ...                          NaN         NaN
# 1          AFG  Afghanistan  ...                         2000         NaN
# 2          AGO       Angola  ...                         2005         NaN
# 3          ALB      Albania  ...                         2006         NaN
# 4          AND      Andorra  ...                          NaN         NaN
#
# [5 rows x 32 columns]

# %%
EdStatsCountry.shape
# Out:
# (241, 32)

# %%
EdStatsData.head()
# Out:
#   Country Name Country Code  ... 2100 Unnamed: 69
# 0   Arab World          ARB  ...  NaN         NaN
# 1   Arab World          ARB  ...  NaN         NaN
# 2   Arab World          ARB  ...  NaN         NaN
# 3   Arab World          ARB  ...  NaN         NaN
# 4   Arab World          ARB  ...  NaN         NaN
#
# [5 rows x 70 columns]

# %%
EdStatsData.shape
# Out:
# (886930, 70)

# %%
EdStatsData.dtypes
# Out:
# Country Name       object
# Country Code       object
# Indicator Name     object
# Indicator Code     object
# 1970              float64
#                    ...
# 2085              float64
# 2090              float64
# 2095              float64
# 2100              float64
# Unnamed: 69       float64
# Length: 70, dtype: object

# %%
EdStatsFootNote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
EdStatsSeries.head()
# Out:
#            Series Code       Topic  ... License Type Unnamed: 20
# 0  BAR.NOED.1519.FE.ZS  Attainment  ...          NaN         NaN
# 1     BAR.NOED.1519.ZS  Attainment  ...          NaN         NaN
# 2  BAR.NOED.15UP.FE.ZS  Attainment  ...          NaN         NaN
# 3     BAR.NOED.15UP.ZS  Attainment  ...          NaN         NaN
# 4  BAR.NOED.2024.FE.ZS  Attainment  ...          NaN         NaN
#
# [5 rows x 21 columns]

# %%
EdStatsData.head()
# Out:
#   Country Name Country Code  ... 2100 Unnamed: 69
# 0   Arab World          ARB  ...  NaN         NaN
# 1   Arab World          ARB  ...  NaN         NaN
# 2   Arab World          ARB  ...  NaN         NaN
# 3   Arab World          ARB  ...  NaN         NaN
# 4   Arab World          ARB  ...  NaN         NaN
#
# [5 rows x 70 columns]

# %%
##### Essayons de travailler avec le jeux de données EdStatsCountrySeries
EdStatsCountrySeries.head()
# Out:
#   CountryCode  ... Unnamed: 3
# 0         ABW  ...        NaN
# 1         ABW  ...        NaN
# 2         AFG  ...        NaN
# 3         AFG  ...        NaN
# 4         AFG  ...        NaN
#
# [5 rows x 4 columns]

# %%
EdStatsCountrySeries.tail()
# Out:
#     CountryCode  ... Unnamed: 3
# 608         ZAF  ...        NaN
# 609         ZMB  ...        NaN
# 610         ZMB  ...        NaN
# 611         ZWE  ...        NaN
# 612         ZWE  ...        NaN
#
# [5 rows x 4 columns]

# %%
# Nombre de ligne et de colonnes du jeux de données.
EdStatsCountrySeries.shape
# Out:
# (613, 4)

# %%
# Le typage des colonnes 
EdStatsCountrySeries.dtypes
# Out:
# CountryCode     object
# SeriesCode      object
# DESCRIPTION     object
# Unnamed: 3     float64
# dtype: object

# %%
# Info
EdStatsCountrySeries.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 613 entries, 0 to 612
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CountryCode  613 non-null    object
#  1   SeriesCode   613 non-null    object
#  2   DESCRIPTION  613 non-null    object
#  3   Unnamed: 3   0 non-null      float64
# dtypes: float64(1), object(3)
# memory usage: 19.3+ KB

# %%
# Variable qualitative 
EdStatsCountrySeries.describe()
# Out:
#        Unnamed: 3
# count         0.0
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# Verifions si le jeux de donnnées EdStatsCountrySeries contient des nulls values 
# Methode 1
EdStatsCountrySeries.isnull().sum()
# Out:
# CountryCode      0
# SeriesCode       0
# DESCRIPTION      0
# Unnamed: 3     613
# dtype: int64

# %%
# verifions les null values 
# Methode 2 
import missingno as msno
msno.matrix(EdStatsCountrySeries)

# %%
# verifions les valeurs unique de la colonnnes Unnamed du jeux de données EdStatsCountrySeries
EdStatsCountrySeries['Unnamed: 3'].unique()
# Out:
# array([nan])

# %%
EdStatsCountrySeries['Unnamed: 3'].values
# Out:
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#        nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
# ...

# %%
# On remarque que cette colonnne n'a que des valeurs nulls elle nous donne aucune information pour pouvoir remplacer les nulls values 
# Comme elle n'est pas pertinente on la supprime
# Supprimer la colonne Unnamed:3 column
EdStatsCountrySeries.drop('Unnamed: 3', axis=1, inplace=True)

# %%
# Verifions le nombre de colonnes et des lignes encore afin de voir si la suppression est effective.
EdStatsCountrySeries.shape
# Out:
# (613, 3)

# %%
EdStatsCountrySeries.head()
# Out:
#   CountryCode  ...                                        DESCRIPTION
# 0         ABW  ...  Data sources : United Nations World Population...
# 1         ABW  ...  Data sources: United Nations World Population ...
# 2         AFG  ...  Data sources: United Nations World Population ...
# 3         AFG  ...                 Estimates are based on regression.
# 4         AFG  ...  Data sources : United Nations World Population...
#
# [5 rows x 3 columns]

# %%
# Verifions les valeurs uniques de la colonne CountryCode 
EdStatsCountrySeries['CountryCode'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARE', 'ARG', 'ARM', 'ASM',
#        'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA', 'BGD',
#        'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL', 'BRA',
#        'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI', 'CHL',
#        'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV', 'CRI',
#        'CUB', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM',
#        'DZA', 'ECU', 'EGY', 'ERI', 'ESP', 'EST', 'ETH', 'FIN', 'FJI',
#        'FRA', 'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN',
#        'GMB', 'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY',
#        'HKG', 'HND', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND', 'IRL',
#        'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN', 'KAZ',
#        'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAO', 'LBN',
#        'LBR', 'LBY', 'LCA', 'LIE', 'LKA', 'LSO', 'LTU', 'LUX', 'LVA',
# ...

# %%
# Nombre de Pays representés
EdStatsCountrySeries['CountryCode'].nunique()
# Out:
# 211

# %%
# Evaluons le nombre de fois que pays est pris en compte.
EdStatsCountrySeries['CountryCode'].value_counts()
# Out:
# GEO    18
# MDA    18
# TZA    12
# MUS    12
# SRB    12
#        ..
# MDG     2
# NAM     2
# IRN     2
# LCA     2
# ITA     2
# Name: CountryCode, Length: 211, dtype: int64

# %%
# Visualisons 
import seaborn as sns 
plt.figure(figsize=(40,10))
sns.countplot(EdStatsCountrySeries['CountryCode'], label='Count')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
# Method 1 :
plt.figure(figsize=(40,8))
plt.hist(EdStatsCountrySeries['CountryCode'], bins=30, rwidth=0.8, range=(0.5, 30.5))
plt.xlabel('Count Country Code ')
plt.ylabel('Country Code')
plt.title('Total Pays')
# Out:
# Text(0.5, 1.0, 'Total Pays')

# %%
EdStatsCountrySeries.head()
# Out:
#   CountryCode  ...                                        DESCRIPTION
# 0         ABW  ...  Data sources : United Nations World Population...
# 1         ABW  ...  Data sources: United Nations World Population ...
# 2         AFG  ...  Data sources: United Nations World Population ...
# 3         AFG  ...                 Estimates are based on regression.
# 4         AFG  ...  Data sources : United Nations World Population...
#
# [5 rows x 3 columns]

# %%
Total_country_Code=EdStatsCountrySeries['CountryCode'].value_counts()

# %%
Total_country_Code
# Out:
# GEO    18
# MDA    18
# TZA    12
# MUS    12
# SRB    12
#        ..
# MDG     2
# NAM     2
# IRN     2
# LCA     2
# ITA     2
# Name: CountryCode, Length: 211, dtype: int64

# %%
plt.figure(figsize=(40,10))
Total_country_Code.plot(kind='bar', style='b', title='')

# %%
Total_Series_Code=EdStatsCountrySeries['SeriesCode'].value_counts()
Total_Series_Code
# Out:
# SP.POP.GROW          211
# SP.POP.TOTL          211
# NY.GNP.PCAP.PP.CD     19
# NY.GDP.PCAP.PP.KD     19
# NY.GDP.PCAP.PP.CD     19
# NY.GDP.MKTP.PP.CD     14
# NY.GDP.MKTP.PP.KD     14
# NY.GNP.MKTP.PP.CD     14
# SP.POP.0014.TO.ZS     13
# SP.POP.TOTL.MA.ZS     13
# SP.POP.1564.TO.ZS     13
# SP.POP.TOTL.FE.ZS     13
# NY.GNP.PCAP.CD         6
# NY.GDP.PCAP.CD         5
# NY.GDP.PCAP.KD         5
# SP.POP.1564.TO         4
# SP.POP.0014.MA.IN      4
# SP.POP.1564.MA.IN      4
# SP.POP.1564.FE.IN      4
# SP.POP.0014.TO         4
# SP.POP.0014.FE.IN      4
# Name: SeriesCode, dtype: int64

# %%
plt.figure(figsize=(40,10))
Total_Series_Code.plot(kind='bar', style='b', title='')

# %%
Total_description=EdStatsCountrySeries['DESCRIPTION'].value_counts()
Total_description
# Out:
# Data sources : United Nations World Population Prospects                                                                                                                       154
# Data sources: United Nations World Population Prospects                                                                                                                        137
# Estimates are based on regression.                                                                                                                                              84
# Data sources : Eurostat                                                                                                                                                         54
# Derived using ratio of age group from WPP and World Bank population.                                                                                                            24
# ...

# %%
plt.figure(figsize=(40,10))
Total_description.plot(kind='bar', style='b', title='')

# %%
plt.figure(figsize=(40,8))
plt.hist(EdStatsCountrySeries['CountryCode'].sort_values(ascending=False), bins=30, rwidth=0.8, range=(0.5, 30.5))
plt.xlabel('Count Country Code ')
plt.ylabel('Country Code')
plt.title('Total Pays')
# Out:
# Text(0.5, 1.0, 'Total Pays')

# %%
#----------------------------------------------------------------------------##-------------------------------------------------------------

# %%
def data_quality_assment(df):
  # sum null values
  total_null_values = df.isnull().sum().sort_values(ascending=False)
  # Pourcentages des valeurs nulls
  percentage_null_values=round(df.isnull().sum()/df.isnull().count()*100,2).sort_values(ascending=False)
  #Typages de données
  info=df.info()
  #Statistiques descriptives
  
  stats=df.describe()
  # Concatenation sum null values and pourcentage
  missing_data=pd.concat([total_null_values, percentage_null_values, info], axis=1, keys=['Total','Pourcentage','Info'])
  visual=msno.matrix(df)
 # print(sum_nan)
 # print(percentage)


  #Print

  print('\n Null values')
  print(missing_data)
  print('\n Visualizations des NaNs', visual)
  print('\n Statistiques descriptives')
  print(stats)

# %%
def extract_cat_num(df):
  cat_col=[col for col in df.columns if df[col].dtype=='object']
  num_col=[col for col in df.columns if df[col].dtype!='object']
  return cat_col, num_col

# %%
data_quality_assment(EdStatsCountry)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 241 entries, 0 to 240
# Data columns (total 32 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Country Code                                       241 non-null    object
#  1   Short Name                                         241 non-null    object
#  2   Table Name                                         241 non-null    object
#  3   Long Name                                          241 non-null    object
#  4   2-alpha code                                       238 non-null    object
#  5   Currency Unit                                      215 non-null    object
#  6   Special Notes                                      145 non-null    object
#  7   Region                                             214 non-null    object
#  8   Income Group                                       214 non-null    object
# ...

# %%
extract_cat_num(EdStatsCountry)
# Out:
# (['Country Code',
#   'Short Name',
#   'Table Name',
#   'Long Name',
#   '2-alpha code',
#   'Currency Unit',
#   'Special Notes',
#   'Region',
#   'Income Group',
#   'WB-2 code',
#   'National accounts base year',
#   'SNA price valuation',
#   'Lending category',
#   'Other groups',
#   'System of National Accounts',
#   'Alternative conversion factor',
#   'PPP survey year',
#   'Balance of Payments Manual in use',
#   'External debt Reporting status',
#   'System of trade',
#   'Government Accounting concept',
#   'IMF data dissemination standard',
#   'Latest population census',
#   'Latest household survey',
#   'Source of most recent Income and expenditure data',
#   'Vital registration complete',
#   'Latest agricultural census',
#   'Latest water withdrawal data'],
#  ['National accounts reference year',
#   'Latest industrial data',
#   'Latest trade data',
#   'Unnamed: 31'])

# %%
#----------------------------------------------------------DATASET EdStatsCountry---------------------------------------------------------------

# %%
EdStatsCountry.sample(2)
# Out:
#     Country Code           Short Name  ... Latest water withdrawal data Unnamed: 31
# 225          UMC  Upper middle income  ...                          NaN         NaN
# 231          VIR       Virgin Islands  ...                          NaN         NaN
#
# [2 rows x 32 columns]

# %%
EdStatsCountry['Country Code'].unique()
# Out:
# array(['ABW', 'AFG', 'AGO', 'ALB', 'AND', 'ARB', 'ARE', 'ARG', 'ARM',
#        'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL', 'BEN', 'BFA',
#        'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ', 'BMU', 'BOL',
#        'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN', 'CHE', 'CHI',
#        'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG', 'COL', 'COM', 'CPV',
#        'CRI', 'CUB', 'CUW', 'CYM', 'CYP', 'CZE', 'DEU', 'DJI', 'DMA',
#        'DNK', 'DOM', 'DZA', 'EAP', 'EAS', 'ECA', 'ECS', 'ECU', 'EGY',
#        'EMU', 'ERI', 'ESP', 'EST', 'ETH', 'EUU', 'FIN', 'FJI', 'FRA',
#        'FRO', 'FSM', 'GAB', 'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB',
#        'GNB', 'GNQ', 'GRC', 'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC',
#        'HKG', 'HND', 'HPC', 'HRV', 'HTI', 'HUN', 'IDN', 'IMN', 'IND',
#        'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA', 'JAM', 'JOR', 'JPN',
#        'KAZ', 'KEN', 'KGZ', 'KHM', 'KIR', 'KNA', 'KOR', 'KWT', 'LAC',
# ...

# %%
EdStatsCountry['Region'].unique()
# Out:
# array(['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa',
#        'Europe & Central Asia', nan, 'Middle East & North Africa',
#        'East Asia & Pacific', 'North America'], dtype=object)

# %%
Group_by_region=EdStatsCountry.groupby('Region')[['Short Name']].count().reset_index().sort_values(by='Short Name', ascending=False)
Group_by_region
# Out:
#                        Region  Short Name
# 1       Europe & Central Asia          57
# 6          Sub-Saharan Africa          48
# 2   Latin America & Caribbean          41
# 0         East Asia & Pacific          36
# 3  Middle East & North Africa          21
# 5                  South Asia           8
# 4               North America           3

# %%
#Nombre de Pays Par Region 
import plotly.express as px 
px.bar(x=EdStatsCountry.groupby('Region')[['Short Name']].count().index,
       y=EdStatsCountry.groupby('Region')[['Short Name']].count(),
       title='Nombre de pays par region')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="aa6c271b-dffe-45c4-9678-da22fcc8ca1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("aa6c271b-dffe-45c4-9678-da22fcc8ca1b")) {
#                     Plotly.newPlot(
#                         'aa6c271b-dffe-45c4-9678-da22fcc8ca1b',
# ...

# %%
# Income Group
EdStatsCountry['Income Group'].unique()
# Out:
# array(['High income: nonOECD', 'Low income', 'Upper middle income', nan,
#        'Lower middle income', 'High income: OECD'], dtype=object)

# %%
#Nombre de Pays Par Income Group
import plotly.express as px 
px.bar(x=EdStatsCountry.groupby('Income Group')[['Short Name']].count().index,
       y=EdStatsCountry.groupby('Income Group')[['Short Name']].count(),
       title='Nombre de pays par Income Group (Revenus)')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2bc2ce77-326f-4011-bfd6-6f4648d6746b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2bc2ce77-326f-4011-bfd6-6f4648d6746b")) {
#                     Plotly.newPlot(
#                         '2bc2ce77-326f-4011-bfd6-6f4648d6746b',
# ...

# %%
#Nombre de Pays Par Income Group
import seaborn as sns 
colors = ['blue','red','black','yellow','green','brown','Blueviolet','aqua']
plt.figure(figsize=(40,20))
sns.countplot(y='Income Group', hue='Region', data=EdStatsCountry,
                   order=['High income: OECD', 'High income: nonOECD', 'Upper middle income', 'Lower middle income', 'Low income'],
                   palette=colors)

# %%
# Lending category
EdStatsCountry['Lending category'].unique()
# Out:
# array([nan, 'IDA', 'IBRD', 'Blend'], dtype=object)

# %%
EdStatsCountry['Lending category'].value_counts()
# Out:
# IBRD     67
# IDA      59
# Blend    18
# Name: Lending category, dtype: int64

# %%
#Nombre de Pays Par Income Group
import plotly.express as px 
px.bar(x=EdStatsCountry.groupby('Lending category')[['Short Name']].count().index,
       y=EdStatsCountry.groupby('Lending category')[['Short Name']].count(),
       title='Nombre de pays par Lending category')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="02b72155-a8ab-4fc6-ab00-6ce72aa6e5d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("02b72155-a8ab-4fc6-ab00-6ce72aa6e5d8")) {
#                     Plotly.newPlot(
#                         '02b72155-a8ab-4fc6-ab00-6ce72aa6e5d8',
# ...

# %%
#------------------------------------ DATASET ( EdStatsFootNote)--------------------------------------------------------------

# %%
EdStatsFootNote.head()
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN
# 2         ABW  SE.PRE.TCHR.FE  YR2000  Country estimation.         NaN
# 3         ABW  SE.SEC.ENRL.GC  YR2004  Country estimation.         NaN
# 4         ABW     SE.PRE.TCHR  YR2006  Country estimation.         NaN

# %%
descript_values_counts=EdStatsFootNote['DESCRIPTION'].value_counts().sort_values(ascending=False)
descript_values_counts
# Out:
# Country Data                                      191188
# UNESCO Institute for Statistics (UIS) estimate    171527
# Estimated                                         117155
# UIS Estimation                                     31395
# Country estimation.                                26308
#                                                    ...
# Uncertainty bound is 77.7 - 80.1                       1
# Uncertainty bound is 140.7 - 161.9                     1
# Uncertainty bound is 79.5 - 140.7                      1
# Uncertainty bound is 3.2 - 4.5                         1
# Uncertainty bound is 143 - 172.1                       1
# Name: DESCRIPTION, Length: 9102, dtype: int64

# %%
series_code_counts=EdStatsFootNote['SeriesCode'].value_counts().sort_values(ascending=False)
series_code_counts
# Out:
# SH.DYN.MORT                  9226
# SE.PRM.DURS                  8771
# SE.PRM.AGES                  8771
# SE.SEC.DURS                  8619
# SE.SEC.AGES                  8581
#                              ...
# UIS.LP.Ag65.F                   1
# SABER.STD.ASS.GOAL2.LVL2        1
# SABER.ERL.CHLD.GOAL1.LVL3       1
# UIS.AFR.TRNTP.2.PU.M            1
# UIS.AFR.TRNTP.3.PU.M            1
# Name: SeriesCode, Length: 1558, dtype: int64

# %%
Year_counts=EdStatsFootNote['Year'].value_counts().sort_values(ascending=False)
Year_counts
# Out:
# YR2004    27128
# YR2005    25992
# YR2002    25687
# YR2003    25683
# YR2000    25093
# YR2001    25047
# YR2008    25018
# YR1999    24938
# YR2007    24263
# YR2006    23394
# YR2009    22965
# YR2010    22598
# YR2011    17760
# YR1998    14916
# YR2012    13890
# YR2013    13405
# YR1994    11448
# YR2014    11378
# YR1992    11309
# YR1996    11197
# YR1995    11194
# YR1997    11167
# YR1991    11129
# YR1993    11093
# YR1990    10616
# YR1986     9743
# YR1985     9653
# YR1989     9517
# YR1981     9465
# YR1984     9386
# YR1988     9382
# YR1987     9357
# YR1983     9227
# YR1982     9014
# YR1980     8950
# YR1979     8742
# YR1976     8729
# YR1972     8661
# YR1975     8627
# YR1977     8593
# YR1978     8585
# YR1973     8571
# YR1974     8512
# YR1971     8507
# YR2015     6348
# YR1970     5374
# YR2016      819
# YR2017      558
# YR2045      144
# YR2040      144
# YR2035      144
# YR2050      144
# YR2025      140
# YR2030      140
# YR2020      140
# ...

# %%
plt.figure(figsize=(40,10))
Year_counts.plot(kind='bar')

# %%
EdStatsFootNote['DESCRIPTION'].sample(10)
# Out:
# 549594    UNESCO Institute for Statistics (UIS) estimate
# 205815    UNESCO Institute for Statistics (UIS) estimate
# 19461                                    UIS estimation.
# 239478                               Country estimation.
# 422158                                      Country Data
# 232638                                    UIS Estimation
# 374304                                         Estimated
# 235105                               National Estimation
# 242039    UNESCO Institute for Statistics (UIS) estimate
# 571458                                         Estimated
# Name: DESCRIPTION, dtype: object

# %%
EdStatsFootNote[EdStatsFootNote['DESCRIPTION'].duplicated()]
# Out:
#        CountryCode  ... Unnamed: 4
# 1              ABW  ...        NaN
# 2              ABW  ...        NaN
# 3              ABW  ...        NaN
# 4              ABW  ...        NaN
# 5              ABW  ...        NaN
# ...            ...  ...        ...
# 643621         ZWE  ...        NaN
# 643622         ZWE  ...        NaN
# 643623         ZWE  ...        NaN
# 643636         ZWE  ...        NaN
# 643637         ZWE  ...        NaN
#
# [634536 rows x 5 columns]

# %%
duplicated_EdStatsFootNote=EdStatsFootNote.copy()

# %%
duplicated_EdStatsFootNote[duplicated_EdStatsFootNote['DESCRIPTION'].duplicated()]
# Out:
#        CountryCode  ... Unnamed: 4
# 1              ABW  ...        NaN
# 2              ABW  ...        NaN
# 3              ABW  ...        NaN
# 4              ABW  ...        NaN
# 5              ABW  ...        NaN
# ...            ...  ...        ...
# 643621         ZWE  ...        NaN
# 643622         ZWE  ...        NaN
# 643623         ZWE  ...        NaN
# 643636         ZWE  ...        NaN
# 643637         ZWE  ...        NaN
#
# [634536 rows x 5 columns]

# %%
duplicated_EdStatsFootNote['DESCRIPTION']=duplicated_EdStatsFootNote['DESCRIPTION'].drop_duplicates()

# %%
#Check again
duplicated_EdStatsFootNote[duplicated_EdStatsFootNote['DESCRIPTION'].duplicated()]
# Out:
#        CountryCode            SeriesCode    Year DESCRIPTION  Unnamed: 4
# 2              ABW        SE.PRE.TCHR.FE  YR2000         NaN         NaN
# 3              ABW        SE.SEC.ENRL.GC  YR2004         NaN         NaN
# 4              ABW           SE.PRE.TCHR  YR2006         NaN         NaN
# 5              ABW           SE.PRE.NENR  YR2000         NaN         NaN
# 6              ABW     SE.SEC.ENRL.VO.FE  YR2005         NaN         NaN
# ...            ...                   ...     ...         ...         ...
# 643621         ZWE  SE.SEC.ENRL.GC.FE.ZS  YR2000         NaN         NaN
# 643622         ZWE        SE.SEC.TCHR.FE  YR1999         NaN         NaN
# 643623         ZWE        SE.SEC.TCHR.FE  YR2003         NaN         NaN
# 643636         ZWE           SH.DYN.MORT  YR2017         NaN         NaN
# 643637         ZWE           SP.POP.GROW  YR2017         NaN         NaN
#
# [634535 rows x 5 columns]

# %%
EdStatsFootNote_year=EdStatsFootNote.copy()

# %%
EdStatsFootNote_year
# Out:
#        CountryCode  ... Unnamed: 4
# 0              ABW  ...        NaN
# 1              ABW  ...        NaN
# 2              ABW  ...        NaN
# 3              ABW  ...        NaN
# 4              ABW  ...        NaN
# ...            ...  ...        ...
# 643633         ZWE  ...        NaN
# 643634         ZWE  ...        NaN
# 643635         ZWE  ...        NaN
# 643636         ZWE  ...        NaN
# 643637         ZWE  ...        NaN
#
# [643638 rows x 5 columns]

# %%
EdStatsFootNote_year['Year'].unique()
# Out:
# array(['YR2001', 'YR2005', 'YR2000', 'YR2004', 'YR2006', 'YR2003',
#        'YR1999', 'YR2008', 'YR2002', 'YR2007', 'YR2017', 'YR2010',
#        'YR2009', 'YR2011', 'YR2012', 'YR2015', 'YR2014', 'YR1970',
#        'YR1971', 'YR1972', 'YR1973', 'YR1974', 'YR1975', 'YR1976',
#        'YR1977', 'YR1978', 'YR1979', 'YR1980', 'YR1981', 'YR1982',
#        'YR1983', 'YR1984', 'YR1985', 'YR1986', 'YR1987', 'YR1988',
#        'YR1989', 'YR1990', 'YR1991', 'YR1992', 'YR1993', 'YR1994',
#        'YR1995', 'YR1996', 'YR1997', 'YR1998', 'YR2013', 'YR2016',
#        'YR2020', 'YR2025', 'YR2030', 'YR2035', 'YR2040', 'YR2045',
#        'YR2050', 'yr2012'], dtype=object)

# %%
EdStatsFootNote_year['Year']=EdStatsFootNote_year['Year'].str.upper()

# %%
EdStatsFootNote_year['Year']
# Out:
# 0         YR2001
# 1         YR2005
# 2         YR2000
# 3         YR2004
# 4         YR2006
#            ...
# 643633    YR2007
# 643634    YR2014
# 643635    YR2015
# 643636    YR2017
# 643637    YR2017
# Name: Year, Length: 643638, dtype: object

# %%
#EdStatsFootNote_year['Year']=EdStatsFootNote_year['Year'].str.split('YR')
EdStatsFootNote_year['YR']=EdStatsFootNote_year['Year'].str[:-4]
EdStatsFootNote_year['Years']=EdStatsFootNote_year['Year'].str[-4:]

# %%
EdStatsFootNote_year.sample(10)
# Out:
#        CountryCode            SeriesCode    Year  ... Unnamed: 4  YR Years
# 413537         MMR  SE.SEC.ENRL.VO.FE.ZS  YR2003  ...        NaN  YR  2003
# 561312         SWE        OECD.TSAL.3.E0  YR2013  ...        NaN  YR  2013
# 395585         MEX        SE.PRE.ENRR.FE  YR1989  ...        NaN  YR  1989
# 400428         MIC     SE.SEC.ENRL.VO.FE  YR1997  ...        NaN  YR  1997
# 579139         THA       UIS.REPR.1.G4.M  YR1999  ...        NaN  YR  1999
# 299061         KNA           SH.DYN.MORT  YR2017  ...        NaN  YR  2017
# 16314          ARE        SE.SEC.TCHR.FE  YR2007  ...        NaN  YR  2007
# 194390         FJI        SE.PRM.CMPT.ZS  YR2009  ...        NaN  YR  2009
# 365040         LSO     UIS.REPR.2.GPV.G3  YR2000  ...        NaN  YR  2000
# 573437         TCD          UIS.NERT.1.M  YR2013  ...        NaN  YR  2013
#
# [10 rows x 7 columns]

# %%
EdStatsFootNote_year.dtypes
# Out:
# CountryCode     object
# SeriesCode      object
# Year            object
# DESCRIPTION     object
# Unnamed: 4     float64
# YR              object
# Years           object
# dtype: object

# %%
EdStatsFootNote_year['Years']=pd.to_numeric(EdStatsFootNote_year['Years'])

# %%
EdStatsFootNote_year.dtypes
# Out:
# CountryCode     object
# SeriesCode      object
# Year            object
# DESCRIPTION     object
# Unnamed: 4     float64
# YR              object
# Years            int64
# dtype: object

# %%
EdStatsFootNote_year['Years'].hist(bins=30)
plt.show()

# %%
EdStatsFootNote.shape
# Out:
# (643638, 5)

# %%
EdStatsFootNote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 643638 entries, 0 to 643637
# Data columns (total 5 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   CountryCode  643638 non-null  object
#  1   SeriesCode   643638 non-null  object
#  2   Year         643638 non-null  object
#  3   DESCRIPTION  643638 non-null  object
#  4   Unnamed: 4   0 non-null       float64
# dtypes: float64(1), object(4)
# memory usage: 24.6+ MB

# %%
EdStatsFootNote.head(2)
# Out:
#   CountryCode      SeriesCode    Year          DESCRIPTION  Unnamed: 4
# 0         ABW  SE.PRE.ENRL.FE  YR2001  Country estimation.         NaN
# 1         ABW  SE.TER.TCHR.FE  YR2005  Country estimation.         NaN

# %%
# Verification des duplication 
# Doublon avec toutes les colonnes du dataframe
# Renvoie une série booléenne indiquant les lignes en double
# Methode 1
EdStatsFootNote[EdStatsFootNote.duplicated(keep=False)].shape[0]
# Out:
# 0

# %%
# Methode Affichage des entrées multiples d'un dataset
EdStatsFootNote[EdStatsFootNote.duplicated()]
# Out:
# Empty DataFrame
# Columns: [CountryCode, SeriesCode, Year, DESCRIPTION, Unnamed: 4]
# Index: []

# %%
# Methode pour le suppression 
EdStatsData[EdStatsData.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Country Name, Country Code, Indicator Name, Indicator Code, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2020, 2025, 2030, 2035, 2040, 2045, 2050, 2055, 2060, 2065, 2070, 2075, 2080, 2085, 2090, 2095, 2100, Unnamed: 69]
# Index: []

# %%
#Doublons avec les deux colonnes CountryCode, SeriesCode 
EdStatsFootNote[EdStatsFootNote.duplicated(['CountryCode','SeriesCode'], keep=False)]
# Out:
#        CountryCode  ... Unnamed: 4
# 0              ABW  ...        NaN
# 1              ABW  ...        NaN
# 2              ABW  ...        NaN
# 3              ABW  ...        NaN
# 4              ABW  ...        NaN
# ...            ...  ...        ...
# 643632         ZWE  ...        NaN
# 643633         ZWE  ...        NaN
# 643634         ZWE  ...        NaN
# 643635         ZWE  ...        NaN
# 643636         ZWE  ...        NaN
#
# [622238 rows x 5 columns]

# %%
doublons_nb=EdStatsFootNote[EdStatsFootNote.duplicated(['CountryCode','SeriesCode'], keep=False)]
print('Doublons entre Country Code & SeriesCode : ', doublons_nb.shape[0])
# Out:
# Doublons entre Country Code & SeriesCode :  622238

# %%
# Check Doublons Description 
ndoublons_descript=EdStatsFootNote[EdStatsFootNote.duplicated(['DESCRIPTION'], keep=False)]
print('Nbre de Doublons dans la colonnes descriptions', ndoublons_descript.shape[0])
# Out:
# Nbre de Doublons dans la colonnes descriptions 635775

# %%
print('Valeurs unique dans la colonne desription : ',EdStatsFootNote['DESCRIPTION'].nunique() )
# Out:
# Valeurs unique dans la colonne desription :  9102

# %%
#### Comparaison de colonnes (Code Code EdStatsCountry and EdSatsFootNote
EdStatsCountry['Country Code'].nunique()==EdStatsFootNote['CountryCode'].nunique()
# Out:
# False

# %%
#----------------------------------------------------------------EdStatsCountry/EStatsFootNote------------------------------

# %%
# Recherche des noms des pays n'apparaissant pas dans le jeu de données EdStatsFootNote.csv
EdStatsCountry[~EdStatsCountry['Country Code'].isin(EdStatsFootNote['CountryCode'])][['Short Name']].sort_values(by = 'Short Name')
# ==> Les pays en plus dans le jeu de données EdStatsCountry sont des noms des pays devenus autonomes (Saint Martin, Groenland).
# Out:
#                     Short Name
# 85                   Greenland
# 207  Sint Maarten (Dutch part)
# 134   St. Martin (French part)

# %%
# Recherche des noms des pays n'apparaissant pas dans le jeu de données EdStatsCountrySeries.csv
EdStatsCountry[~EdStatsCountry['Country Code'].isin(EdStatsCountrySeries['CountryCode'])][['Short Name']].sort_values(by = 'Short Name')
# Out:
#                                          Short Name
# 5                                        Arab World
# 47                                          Curaçao
# 58          East Asia & Pacific (all income levels)
# 57            East Asia & Pacific (developing only)
# 63                                        Euro area
# 60        Europe & Central Asia (all income levels)
# 59          Europe & Central Asia (developing only)
# 68                                   European Union
# 92           Heavily indebted poor countries (HIPC)
# 89                                      High income
# 122   Latin America & Caribbean (all income levels)
# 116     Latin America & Caribbean (developing only)
# 123    Least developed countries: UN classification
# 128                             Low & middle income
# 124                                      Low income
# 127                             Lower middle income
# 140  Middle East & North Africa (all income levels)
# ...

# %%
# Recherche des noms des pays n'apparaissant pas dans le jeu de données EdStatsData.csv
EdStatsCountry[~EdStatsCountry['Country Code'].isin(EdStatsData['Country Code'])][['Short Name']].sort_values(by = 'Short Name')
# Out:
# Empty DataFrame
# Columns: [Short Name]
# Index: []

# %%
#-----------------------------------------------------------------------------------------11111-----------------------------------------

# %%
# les topic les plus frequent 
EdStatsSeries.head(2)
# Out:
#            Series Code       Topic  ... License Type Unnamed: 20
# 0  BAR.NOED.1519.FE.ZS  Attainment  ...          NaN         NaN
# 1     BAR.NOED.1519.ZS  Attainment  ...          NaN         NaN
#
# [2 rows x 21 columns]

# %%
EdStatsSeries.sample(5)
# Out:
#                   Series Code               Topic  ... License Type Unnamed: 20
# 352         BAR.TER.SCHL.6064          Attainment  ...          NaN         NaN
# 2999                UIS.G.7.F            Tertiary  ...          NaN         NaN
# 3180            UIS.NART.2.Q1  Education Equality  ...          NaN         NaN
# 930   LO.EGRA.READ.0.ENG.2GRD   Learning Outcomes  ...          NaN         NaN
# 682     LO.EGRA.CWPM.KIS.2GRD   Learning Outcomes  ...          NaN         NaN
#
# [5 rows x 21 columns]

# %%
data_quality_assment(EdStatsSeries)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3665 entries, 0 to 3664
# Data columns (total 21 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Series Code                          3665 non-null   object
#  1   Topic                                3665 non-null   object
#  2   Indicator Name                       3665 non-null   object
#  3   Short definition                     2156 non-null   object
#  4   Long definition                      3665 non-null   object
#  5   Unit of measure                      0 non-null      float64
#  6   Periodicity                          99 non-null     object
#  7   Base Period                          314 non-null    object
#  8   Other notes                          552 non-null    object
#  9   Aggregation method                   47 non-null     object
#  10  Limitations and exceptions           14 non-null     object
# ...

# %%
# on peut supprimer toutes les colonnes contenant 100% de valeurs nulls 
EdStatsSeries.drop(['Unnamed: 20','Related indicators','Other web links','Unit of measure','License Type','Notes from original source'], axis=1, inplace=True)

# %%
# Verifier encore les nulls values 
EdStatsSeries.isnull().sum()
# Out:
# Series Code                               0
# Topic                                     0
# Indicator Name                            0
# Short definition                       1509
# Long definition                           0
# Periodicity                            3566
# Base Period                            3351
# Other notes                            3113
# Aggregation method                     3618
# Limitations and exceptions             3651
# General comments                       3651
# Source                                    0
# Statistical concept and methodology    3642
# Development relevance                  3662
# Related source links                   3450
# dtype: int64

# %%
# Verifier le contenu des colonnes contenant des nulls values, pour voir s'il ya une possibilité de remplacer les nulls values.
EdStatsSeries['Periodicity'].unique()
# Out:
# array([nan, 'Annual'], dtype=object)

# %%
EdStatsSeries['Related source links'].unique()
# Out:
# array([nan, 'http://saber.worldbank.org/index.cfm'], dtype=object)

# %%
EdStatsSeries['Base Period'].unique()
# Out:
# array([nan, '2010', '2011', 'Projections (2010 to 2100)', '14'],
#       dtype=object)

# %%
EdStatsSeries['Short definition'].unique()
# Out:
# array(['Percentage of female population age 15-19 with no education',
#        'Percentage of population age 15-19 with no education',
#        'Percentage of female population age 15+ with no education', ...,
#        'Average total (current, capital and transfers) general government expenditure per student in the given level of education, expressed in nominal purchasing power parity (PPP) dollars. Divide total government expenditure (in PPP$) for a given level of education (ex. primary, secondary) by total enrolment in that same level. For more information, consult the UNESCO Institute of Statistics website: http://www.uis.unesco.org/Education/',
# ...

# %%
EdStatsSeries['Topic'].value_counts()
# Out:
# Learning Outcomes                                                                               1046
# Attainment                                                                                       733
# Education Equality                                                                               426
# Secondary                                                                                        256
# Primary                                                                                          248
# Population                                                                                       213
# Tertiary                                                                                         158
# Teachers                                                                                         137
# Expenditures                                                                                      93
# ...

# %%
# visualization des topic les plus frequent 
Topic_EdStatsSeries=EdStatsSeries['Topic'].value_counts().sort_values(ascending=False)
Topic_EdStatsSeries
# Out:
# Learning Outcomes                                                                               1046
# Attainment                                                                                       733
# Education Equality                                                                               426
# Secondary                                                                                        256
# Primary                                                                                          248
# Population                                                                                       213
# Tertiary                                                                                         158
# Teachers                                                                                         137
# Expenditures                                                                                      93
# ...

# %%
plt.figure(figsize=(40,30))
Topic_EdStatsSeries.plot(kind='barh')

# %%
# les Top 10 topic 
topic_top_10=EdStatsSeries['Topic'].value_counts().sort_values(ascending=False).head(10)
topic_10
# Out:
# Learning Outcomes                      1046
# Attainment                              733
# Education Equality                      426
# Secondary                               256
# Primary                                 248
# Population                              213
# Tertiary                                158
# Teachers                                137
# Expenditures                             93
# Engaging the Private Sector (SABER)      51
# Name: Topic, dtype: int64

# %%
topic_10.plot(kind='barh')

# %%
topic_last_10=EdStatsSeries['Topic'].value_counts().sort_values(ascending=False).tail(10)
topic_last_10
# Out:
# Laber                                                                                           3
# Economic Policy & Debt: National accounts: US$ at current prices: Aggregate indicators          3
# Economic Policy & Debt: National accounts: US$ at constant 2010 prices: Aggregate indicators    2
# Background                                                                                      2
# Infrastructure: Communications                                                                  2
# EMIS                                                                                            2
# Health: Mortality                                                                               1
# Economic Policy & Debt: National accounts: Atlas GNI & GNI per capita                           1
# Health: Population: Dynamics                                                                    1
# Health: Risk factors                                                                            1
# ...

# %%
topic_last_10.plot(kind='barh')

# %%
EdStatsSeries.head(2)
# Out:
#            Series Code       Topic  ... Development relevance Related source links
# 0  BAR.NOED.1519.FE.ZS  Attainment  ...                   NaN                  NaN
# 1     BAR.NOED.1519.ZS  Attainment  ...                   NaN                  NaN
#
# [2 rows x 15 columns]

# %%
import plotly.express as px

# %%
# 2 Methode
import plotly.express as px 
px.bar(x=EdStatsSeries['Topic'].value_counts().index,
       y=EdStatsSeries['Topic'].value_counts(), height=1000)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="c55600d4-aa87-446f-b4c3-02fc739c3cf9" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c55600d4-aa87-446f-b4c3-02fc739c3cf9")) {
#                     Plotly.newPlot(
#                         'c55600d4-aa87-446f-b4c3-02fc739c3cf9',
# ...

# %%
##-----------------------------------------------EdStatsData---------------------------------------------------------------

# %%
EdStatsData.sample(5)
# Out:
#        Country Name Country Code  ... 2100 Unnamed: 69
# 860475      Vanuatu          VUT  ...  NaN         NaN
# 447524        Japan          JPN  ...  NaN         NaN
# 610933  New Zealand          NZL  ...  NaN         NaN
# 771103     Suriname          SUR  ...  NaN         NaN
# 773620    Swaziland          SWZ  ...  NaN         NaN
#
# [5 rows x 70 columns]

# %%
# Data quality assessment 
data_quality_assment(EdStatsData)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 886930 entries, 0 to 886929
# Data columns (total 70 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    886930 non-null  object
#  1   Country Code    886930 non-null  object
#  2   Indicator Name  886930 non-null  object
#  3   Indicator Code  886930 non-null  object
#  4   1970            72288 non-null   float64
#  5   1971            35537 non-null   float64
#  6   1972            35619 non-null   float64
#  7   1973            35545 non-null   float64
#  8   1974            35730 non-null   float64
#  9   1975            87306 non-null   float64
#  10  1976            37483 non-null   float64
#  11  1977            37574 non-null   float64
#  12  1978            37576 non-null   float64
#  13  1979            36809 non-null   float64
#  14  1980            89122 non-null   float64
#  15  1981            38777 non-null   float64
# ...

# %%
# Supprimer Unnamed: 69 car il a 100 % de nulls values
EdStatsData.drop(['Unnamed: 69'], axis=1, inplace=True)

# %%
EdStatsData['2017'].unique()
# Out:
# array([nan,  2.,  4.,  3.,  1.])

# %%
EdStatsData['2016'].unique()
# Out:
# array([           nan, 2.19231684e+13, 2.24804279e+13, ...,
#        7.86227600e+06, 4.86817350e+01, 1.61503620e+07])

# %%
EdStatsData['1971'].unique()
# Out:
# array([        nan, 54.89413834, 43.31814957, ...,  0.36193001,
#         0.54605001,  0.08592   ])
